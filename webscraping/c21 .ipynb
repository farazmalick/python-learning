# %%
import requests
from bs4 import BeautifulSoup

r=requests.get("http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/")
c=r.content

soup=BeautifulSoup(c,"html.parser")


all = soup.find_all("div",{"class":"propertyRow"})



all[0].find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")
# Out:
# '$725,000'

# %%
l=[]
for item in all:
    d={}
    d["price"]=item.find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")
    d["address"]=item.find_all("span",{"class":"propAddressCollapse"})[0].text
    d["locality"]=item.find_all("span",{"class":"propAddressCollapse"})[1].text
    try:
        d["beds"]=item.find("span",{"class":"infoBed"}).find("b").text
    except:
        d["beds"]=None
    try:
        d["area"]=item.find("span",{"class":"infoSqFt"}).find("b").text
    except:
        d["area"]=None
    try:
        d["full bath"]=item.find("span",{"class":"infoValueFullBath"}).find("b").text
    except:
        d["beds"]=None
    try:
        d["half bath"]=item.find("span",{"class":"infoValueHalfBath"}).find("b").text
    except:
        d["half bath"]=None
    """"    
    for col_group in item.find_all("div",{"class":"columnGroup"}):
        for ft_group,ft_name in zip(col_group.find_all("span",{"class":"featureGroup"}),col_group.find_all("span",{"class":"featureName"})):
            #print(ft_group.txt,ft_name.txt)
            if "Lot Size" in ft_group.txt:
            print(ft_name.txt)
    """
    l.append(d)

# %%
l
# Out:
# [{'price': '$725,000',
#   'address': '0 Gateway',
#   'locality': 'Rock Springs, WY 82901',
#   'beds': None,
#   'area': None,
#   'half bath': None},
#  {'price': '$452,900',
#   'address': '1003 Winchester Blvd.',
#   'locality': 'Rock Springs, WY 82901',
#   'beds': '4',
#   'area': None,
#   'full bath': '4',
#   'half bath': None},
#  {'price': '$396,900',
#   'address': '600 Talladega',
#   'locality': 'Rock Springs, WY 82901',
#   'beds': '5',
#   'area': '3,154',
#   'full bath': '3',
#   'half bath': None},
#  {'price': '$389,900',
#   'address': '3239 Spearhead Way',
#   'locality': 'Rock Springs, WY 82901',
#   'beds': '4',
#   'area': '3,076',
#   'full bath': '3',
#   'half bath': '1'},
#  {'price': '$254,000',
#   'address': '522 Emerald Street',
#   'locality': 'Rock Springs, WY 82901',
#   'beds': '3',
#   'area': '1,172',
#   'full bath': '3',
#   'half bath': None},
#  {'price': '$252,900',
#   'address': "1302 Veteran's Drive",
# ...

# %%
import pandas
df=pandas.DataFrame(l)
df
# Out:
#       price                address                locality  beds   area  \
# 0  $725,000              0 Gateway  Rock Springs, WY 82901  None   None
# 1  $452,900  1003 Winchester Blvd.  Rock Springs, WY 82901     4   None
# 2  $396,900          600 Talladega  Rock Springs, WY 82901     5  3,154
# 3  $389,900     3239 Spearhead Way  Rock Springs, WY 82901     4  3,076
# 4  $254,000     522 Emerald Street  Rock Springs, WY 82901     3  1,172
# 5  $252,900   1302 Veteran's Drive  Rock Springs, WY 82901     4  1,932
# 6  $210,000       1021 Cypress Cir  Rock Springs, WY 82901     4  1,676
# 7  $209,000         913 Madison Dr  Rock Springs, WY 82901     3  1,344
# 8  $199,900      1344 Teton Street  Rock Springs, WY 82901     3  1,920
# 9  $196,900         4 Minnies Lane  Rock Springs, WY 82901     3  1,664
#
#   half bath full bath
# 0      None       NaN
# 1      None         4
# 2      None         3
# 3         1         3
# 4      None         3
# 5      None         2
# ...

# %%
df.to_csv("c21.csv")

# %%
base_url="http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/#t=0&s="
for page in range(0,30,10):
    print(base_url+str(page)+".html")
# Out:
# http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/#t=0&s=0.html
# http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/#t=0&s=10.html
# http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/#t=0&s=20.html
